# %% [markdown]
# ### 練習 1：圓的面積和周長
#
# **題目陳述：**
# 編寫一個程式，根據給定的半徑計算圓的面積和周長。半徑應作為變數定義。使用 `math` 模組進行計算。
#
# ### 練習 2：直角三角形的斜邊
#
# **題目陳述：**
# 編寫一個程式，根據直角三角形的兩條邊的長度計算斜邊的長度。兩條邊的長度應作為變數定義。使用 `math` 模組進行計算。
#
# ### 練習 3：統計計算
#
# **題目陳述：**
# 編寫一個程式，計算五個數字的平均值、變異數(variance)和標準差(standard deviation)。五個數字應作為獨立的變數定義。使用 `math` 模組進行計算。

# %% [markdown]
# ### 練習 4：字串處理
#
# **題目陳述：**
# 編寫一個程式，將字串 "  Welcome to Python programming.   " 進行以下的連續操作：
# 1. 移除字串前後的空白字元。
# 2. 將字串轉換為大寫。
# 3. 分割字串並顯示每個單字。
