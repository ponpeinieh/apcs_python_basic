# %% [markdown]
# ### `__new__()` 方法介紹
#
# 在 Python 中，`__new__()` 是一個特殊的方法，用於建立類別的實例(物件)。它在類別的實例被建立之前被呼叫，主要是用於控制物件的建立過程。這個方法的主要用途包括：
#
# - **建立物件**：`__new__()` 方法負責回傳一個新的物件。
# - **控制物件的建立行為**：您可以在 `__new__()` 中添加邏輯來決定是否建立新物件，或是回傳已存在的物件。
#
# #### 方法簽名
#
# ```python
# def __new__(cls, *args, **kwargs):
#     # 建立一個新物件的實例
#     instance = super().__new__(cls) # 呼叫父類別的__new__(), 這也是預設行爲
#     return instance
# ```
#
# - `cls` 參數是類別本身，與 `self` 不同，`self` 是實例本身。
# - `*args` 和 `**kwargs` 使得您可以傳遞任意數量的參數。
#
# #### 使用 `__new__()`
#
# ```python
# class MyClass:
#     def __new__(cls, *args, **kwargs):
#         print("建立實體物件...")
#         # 通過父類別的 __new__() 建立物件實例
#         instance = super().__new__(cls)
#         return instance
#
#     def __init__(self, value):
#         print("初始化物件...")
#         self.value = value
#
# # 建立 MyClass 的實例
# obj = MyClass(10)  # 輸出：建立實體物件...
#                    # 輸出：初始化物件...
# ```
#
# #### `__new__()` 與 `__init__()` 的區別
#
# - **`__new__()`**：
#   - 負責建立物件。
#   - 回傳一個新的物件。
#   - 當需要控制**物件建立過程**時可以改寫内容，例如**單例(Singleton)模式**或**不可變(Immutable)類別型**（如元組和字串）。
#
# - **`__init__()`**：
#   - 負責初始化物件的屬性。
#   - 接受已建立的物件( `self`參數)。
#   - 在 `__new__()` 呼叫完成之後被呼叫。
#
# #### 使用場景
#
# 1. **單例(Singleton)模式**：如果您希望類別只有一個實例，您可以在 `__new__()` 中檢查是否已經存在該實例，如果存在就不產生新的實例，並回傳該實例。
#
# 2. **不可變(Immutable)類別型**：像元組和字串這樣的不可變類別型通常會重寫 `__new__()` 方法來回傳一個已經存在的實例。

# %% [markdown]
# ### `__del__` 方法
#
# `__del__` 方法是 Python 中的一個特殊方法，用於定義物件的**解構**(Destructor)行為。這個方法在物件被垃圾回收（即不再被引用時）時自動呼叫。
#
# ### `__del__` 方法的用途
#
# - **資源釋放**：當物件不再需要時，`__del__` 方法可以用來釋放資源，例如關閉文件或網絡連接。
# - **清理操作**：可以執行一些清理操作，如記錄日誌或通知其他系統物件。
#
# #### 範例
#
# ```python
# class MyClass:
#     def __init__(self, name):
#         self.name = name
#         print(f"{self.name} 被建立。")
#
#     def __del__(self):
#         print(f"{self.name} 被銷毀，執行解構行為。")
#
# # 建立物件
# obj = MyClass("物件1")
#
# # 刪除物件
# del obj  # 此時會呼叫 __del__ 方法
# ```
#
# 執行結果：
# ```
# 物件1 被建立。
# 物件1 被銷毀，執行解構行為。
# ```
#
# ### 注意事項
#
# 1. **不保證即時執行**：`__del__` 方法的執行時間不一定是即時的，因為 Python 的垃圾回收機制可能會延遲釋放物件。
#
# 2. **循環引用問題**：如果物件之間存在循環引用（彼此引用），`__del__` 方法可能不會被呼叫，因為垃圾回收無法確定這些物件何時可以被釋放。
#
# 3. **避免使用**：過度依賴 `__del__` 方法的作法並不推薦，因為它可能導致難以預測的行為。通常建議使用**上下文管理器**（`with` 語句）來處理資源。
#
# ### 進階範例: 使用 `__del__` 方法來釋放資源：
#
# ```python
# class FileHandler:
#     def __init__(self, filename):
#         self.file = open(filename, 'w')
#         print(f"已打開文件: {filename}")
#
#     def write(self, content):
#         self.file.write(content)
#
#     def __del__(self):
#         self.file.close()
#         print("文件已關閉。")
#
# # 使用 FileHandler
# handler = FileHandler("example.txt")
# handler.write("Hello, World!")
#
# # 刪除物件
# del handler  # 此時會呼叫 __del__ 方法，關閉文件
# ```
#
# 執行結果：
# ```
# 已打開文件: example.txt
# 文件已關閉。
# ```

# %% [markdown]
# ### 單例模式的實作
#
# 建立一個名為 `Singleton` 的類別，確保它在整個應用程序中只有一個實例。
#
# ```python
# class Singleton:
#     _instance = None  # Class variable to hold the single instance
#
#     def __new__(cls, *args, **kwargs):
#         if cls._instance is None:
#             cls._instance = super().__new__(cls)  # Create instance if it doesn't exist
#         return cls._instance
#
# # Using the example
# singleton1 = Singleton()
# singleton2 = Singleton()
#
# # Print the IDs of the instances
# print(id(singleton1))  # Output: ID of the first instance
# print(id(singleton2))  # Output: ID of the second instance (should be the same as singleton1)
# ```
#
# ---
#
# Another implementation with some improvement
#
# ```python
# class Singleton:
#     _instance = None  # 類別變數，用於儲存唯一的實例
#
#     def __new__(cls, *args, **kwargs):
#         if cls._instance is None:  # 如果實例尚未建立
#             cls._instance = super().__new__(cls)  # 建立新實例
#         return cls._instance  # 回傳已存在的實例
#
#     def __init__(self, value): # 初始化動作也要確保只做一次
#         if not hasattr(self, 'initialized'):
#             self.value = value
#             self.initialized = True  # 設置Flag以避免再次初始化
#
# # 使用 Singleton 類別
# singleton1 = Singleton(10)
# print(singleton1.value)  # 輸出：10
#
# # 嘗試建立另一個 Singleton 實例
# singleton2 = Singleton(20) # 20 is not used!
# print(singleton2.value)  # 輸出：10，因為它是同一個實例
#
# # 驗證兩個變數指向同一個實例
# print(singleton1 is singleton2)  # 輸出：True
# ```

# %% [markdown]
# ### 不可變類別型(Immutable)的實作
#
# 1. **不可變類別型**：
#    - 像 `int`、`str` 和 `tuple` 這些類別型是不可變的，這意味著一旦它們被建立，其值就無法改變。這種不可變性有助於在記憶體使用和性能上進行優化。
#
# 2. **`__new__` 方法**：
#    - `__new__` 方法負責建立類別的實例。它在 `__init__` 之前被呼叫。
#    - 對於不可變類別型，`__new__` 可以檢查是否已經存在相同的實例。如果存在，它可以回傳現有的實例，而不是建立一個新的。
#    - 通過重寫 `__new__`，像 `int`、`str` 和 `tuple` 這些類別型可以實作重用現有實例的邏輯。例如，如果你建立了兩個相同的字串，Python 可以為這兩個字串回傳相同的字串物件，從而節省記憶體並提高性能。
#    - 這種行為在小整數和短字串中特別明顯，Python 對它們進行緩存以優化資源使用。

# %% [markdown]
# ### `__setattr__` 方法
#
# 在 Python 中，`__setattr__()` 是一個特殊方法，用於設置物件的屬性。在實現不可變物件時，覆蓋這個方法至關重要，原因如下：
#
# 1. **控制屬性賦值**：通過覆蓋 `__setattr__()`，可以有效地控制屬性的賦值方式，防止在物件初始化後對變數進行更改。
#
# 2. **防止意外修改**：如果不實現 `__setattr__()`，當嘗試更改屬性時，Python 會默認允許這樣的操作，這可能導致意外修改那些應該是不可變的屬性。
#
# 3. **維護一致性和完整性**：實現 `__setattr__()` 有助於確保物件的狀態保持一致和完整，確保物件一旦創建，其狀態不會改變，這對於某些應用（如函數式編程和並發編程）尤為重要。
#
# 為了正確實現不可變物件並確保屬性在實例建立後無法被修改，我們必須實作 `__setattr__()`。同時，在 `__new__()` 方法中應**避免直接設置私有屬性**，因為這樣會觸發對 `__setattr__()` 的呼叫，進而引發 `AttributeError`。
#
# ### 不可變類別型實作範例
#
# ```python
# class ImmutablePoint:
#     _instances = {}  # dict用於儲存已建立的實例
#
#     def __new__(cls, x, y):
#         # 使用座標(x,y)作為dict鍵來檢查是否已經存在實例
#         key = (x, y)
#         if key not in cls._instances:
#             # 建立新實例
#             instance = super().__new__(cls)
#             # 避免直接設置屬性，而是透過 __dict__ 來設置，否則會呼叫 __setattr__()
#             instance.__dict__['_x'] = x
#             instance.__dict__['_y'] = y
#             cls._instances[key] = instance  # 儲存實例
#             return instance  # 返回新實例
#         return cls._instances[key]  # 返回現有的實例
#
#     def __init__(self, x, y):
#         # 初始化方法不需要執行任何操作
#         pass
#
#     @property
#     def x(self):
#         return self._x  # 獲取私有屬性
#
#     @property
#     def y(self):
#         return self._y  # 獲取私有屬性
#
#     def __setattr__(self, name, value):
#         # 禁止設置屬性，確保不可變性
#         raise AttributeError(f"{name} 是不可變的，無法進行修改。")
#
# # 使用 ImmutablePoint 類別
# point1 = ImmutablePoint(1, 2)
# print(f"Point1: ({point1.x}, {point1.y})")  # 輸出：Point1: (1, 2)
#
# # 嘗試建立相同的 ImmutablePoint 實例
# point2 = ImmutablePoint(1, 2)
# print(f"Point2: ({point2.x}, {point2.y})")  # 輸出：Point2: (1, 2)
#
# # 驗證兩個變數指向同一個實例
# print(point1 is point2)  # 輸出：True，因為它們是同一個實例
#
# # 嘗試建立不同的 ImmutablePoint 實例
# point3 = ImmutablePoint(3, 4)
# print(f"Point3: ({point3.x}, {point3.y})")  # 輸出：Point3: (3, 4)
#
# # 驗證不同實例
# print(point1 is point3)  # 輸出：False，因為它們是不同的實例
#
# # 嘗試修改 x 和 y 屬性
# try:
#     point1.x = 5  # 嘗試修改 x
# except AttributeError as e:
#     print(e)  # 輸出：x 是不可變的，無法進行修改。
#
# try:
#     point1.y = 6  # 嘗試修改 y
# except AttributeError as e:
#     print(e)  # 輸出：y 是不可變的，無法進行修改。
# ```
#
# ### 代碼解析
#
# 1. **使用 `instance.__dict__`**：
#    - 在 `__new__()` 方法中，我們使用 `instance.__dict__` 來設置屬性 `_x` 和 `_y`。這樣可以避免呼叫 `__setattr__()`，從而避免引發 `AttributeError`。
#
# 2. **私有屬性**：
#    - 使用 `_x` 和 `_y` 作為屬性名稱，這樣可以避免名稱修飾的問題。
#
# 3. **不可變性**：
#    - `__setattr__()` 方法禁止對任何屬性的修改，確保這些屬性保持不可變。

# %% [markdown]
# ### `__dict__` 屬性
#
# 在 Python 中，`__dict__` 是一個內建屬性，用於存儲類別和實例的可寫屬性，並以字典型態表示。這個字典包含了物件的所有實例變數（屬性）及其對應的值，並且對於類別而言，還包含類別的屬性和所有方法（包括實體方法、類別方法和靜態方法）。
#
# 1. **實例的 `__dict__`**：
#    - 對於類別的實例，`instance.__dict__` 會包含該實例所定義的所有屬性。例如：
#      ```python
#      class MyClass:
#          def __init__(self, value):
#              self.value = value
#
#      obj = MyClass(10)
#      print(obj.__dict__)  # 輸出: {'value': 10}
#      ```
#
# 2. **類別的 `__dict__`**：
#    - 對於類別本身，`ClassName.__dict__` 包含類別的屬性和所有方法(包括實體方法、類別方法和靜態方法)。例如：
#      ```python
#      class MyClass:
#          class_var = 10
#
#          def instance_method(self):
#              return "這是實體方法"
#
#          @classmethod
#          def class_method(cls):
#              return "這是類別方法"
#
#          @staticmethod
#          def static_method():
#              return "這是靜態方法"
#
#      print(MyClass.__dict__)
#      # 輸出: {'__module__': '__main__', 'class_var': 10, 'instance_method': <function MyClass.instance_method at ...>,
#      # 'class_method': <function MyClass.class_method at ...>, 'static_method': <function MyClass.static_method at ...>, ...}
#      ```
#
# 3. **可寫屬性**：
#    - 存儲在 `__dict__` 中的屬性可以被動態修改。您可以使用這個字典來添加、修改或刪除屬性。
#
# 4. **自定義屬性訪問**：
#    - 您可以通過重寫 `__setattr__()` 和 `__getattr__()` 等方法來自定義屬性的訪問和修改行為。
#
# 5. **繼承的屬性**：
#    - 繼承的屬性不會出現在實例的 `__dict__` 中，除非它們被重寫。Python 將會按照方法解析順序（MRO）來查找父類別中的屬性。
#
# ### 範例
#
# 這是一個簡單的範例，展示 `__dict__` 的用法：
#
# ```python
# class Person:
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
# # 建立 Person 類別的實例
# person = Person("Alice", 30)
#
# # 訪問 __dict__ 屬性
# print(person.__dict__)  # 輸出: {'name': 'Alice', 'age': 30}
#
# # 透過 __dict__ 修改屬性
# person.__dict__['age'] = 31
# print(person.age)  # 輸出: 31
# ```

# %% [markdown]
# `__call__` 方法是 Python 中的一個特殊方法，允許類別的實例像函數一樣被呼叫。這意味著當你在類別中定義 `__call__` 時，你可以創建可以用括號呼叫的物件，就像普通函數一樣。
#
# ### `__call__` 的運作原理
#
# 當你在類別中定義了 `__call__` 方法後，你可以指定任何你想要的參數，當你呼叫該類別的實例時，Python 將執行 `__call__` 方法。
#
# ### `__call__` 的使用案例
#
# 1. **似函數的物件**：
#    - 可以創建像函數一樣運作的物件，封裝行為和狀態。
#
# 2. **裝飾器**：
#    - 可以使用 `__call__` 方法創建裝飾器，以修改函數或方法的行為。
#
# 3. **有狀態的函數**：
#    - 保持跨函數呼叫的狀態。當需要跟踪多次呼叫中的數據時，這非常有用。

# %% [markdown]
# ### 似函數的物件，封裝行為和狀態
#
# ```python
# class Adder:
#     def __init__(self, increment):
#         self.increment = increment
#
#     def __call__(self, value):
#         return value + self.increment
#
# # 創建 Adder 的實例，增量為 5
# add_five = Adder(5)
#
# # 像函數一樣呼叫這個實例
# result = add_five(10)
# print(result)  # 輸出：15
# ```

# %% [markdown]
# ### 裝飾器（decorators）
#
# - 裝飾器允許修改或增強函數或方法的行為，而不需要直接修改它們的代碼。使用 `__call__` 方法的類別可以輕鬆地創建這些裝飾器。
#
# - 裝飾器實際上是一個接受一個函數作為參數並返回另一個函數的函數。這樣，你可以在不改變原始函數的情況下，為其添加額外的功能。裝飾器常用於以下幾種情況：
#
#     - 記錄日誌
#     - 性能測試
#     - 計算函數的執行時間
#     - 檢查權限或身份驗證
#     - 緩存結果
#
# #### 範例：計算函數執行時間的裝飾器
#
# ```python
# import time
#
# class Timer:
#     def __call__(self, func):
#         def wrapper(*args, **kwargs):
#             start_time = time.time()  # 記錄開始時間
#             result = func(*args, **kwargs)  # 調用原始函數
#             end_time = time.time()  # 記錄結束時間
#             print(f"執行 {func.__name__} 耗時 {end_time - start_time:.4f} 秒")
#             return result
#         return wrapper
#
# # 使用裝飾器
# @Timer()
# def slow_function(seconds):
#     time.sleep(seconds)
#     return "完成"
#
# # 測試裝飾器
# print(slow_function(2))  # 執行時間會被計算並顯示
# ```

# %% [markdown]
# ### 保持跨函數呼叫的狀態
#
# - 計數器的功能：
#
# ```python
# class Counter:
#     def __init__(self):
#         self.count = 0
#
#     def __call__(self):
#         self.count += 1
#         return self.count
#
# # 創建 Counter 的實例
# counter = Counter()
#
# # 多次呼叫計數器
# print(counter())  # 輸出：1
# print(counter())  # 輸出：2
# print(counter())  # 輸出：3
# ```
#
# 在這個例子中：
# - `Counter` 類別有一個內部屬性 `count`，初始為 0。
# - 每當實例被呼叫時，`count` 會增加 1，並返回新的計數值。
