# %% [markdown]
# ### 練習題 1：成績分類
#
# **描述**：寫一段程式碼，接受一個數字成績（0-100），並根據以下標準顯示字母等級：
# - A: 90-100
# - B: 80-89
# - C: 70-79
# - D: 60-69
# - F: 0-59
#
# ### 練習題 2：多位學生成績分類
#
# **描述**：擴展以上的練習，建立一個字典（`dict`）來儲存多位學生的成績（0-100），並根據上一個練習中的分數等級標準顯示每位學生的字母等級。
#
# **要求**：
# 1. 手動建立一個字典，儲存學生的姓名和成績。
# 2. 使用 `for` 迴圈遍歷字典中的每位學生及其成績，輸出每位學生的名字及其對應的等級。
#
# **範例學生名單及成績**：
# - Alice: 95
# - Bob: 82
# - Charlie: 76
# - David: 58
# - Eva: 66
#
# ### 練習題 3：九宮格(3x3 網格座標)檢查
#
# **描述**：寫一段程式碼，接受 x 和 y 座標（0-2），並根據以下標準判斷座標的位置，然後顯示相應的訊息：
# - 如果座標在網格範圍內，顯示 "座標在網格內有效。"
# - 如果座標在網格範圍外，顯示 "座標無效！請輸入 0 到 2 之間的值。"
# - 如果座標為負數，顯示 "座標不能為負數！"
# - 如果座標在中心（1, 1），顯示 "您在網格的中心。"
# - 如果座標在角落 (例如 (0, 0), (0, 2), (2, 0), 或 (2, 2))，顯示 "您在網格的角落。"
# - 如果座標在邊緣但不是角落 (例如 (0, 1), (1, 0), (1, 2), 或 (2, 1))，顯示 "您在網格的邊緣。"
#
# ### 練習題 4：偶數平方總和計算
#
# **描述**：寫一段程式碼，使用 `for` 迴圈和 `range()` 函數，計算從 2 到 20 的所有偶數的平方總和，並顯示平方的公式形式。
#
# **要求**：
# 1. 使用 `for` 迴圈遍歷從 2 到 20 的偶數。
# 2. 在迴圈結束後，顯示所有偶數的平方總和及其公式形式（例如 `2^2 + 4^2 + 6^2 + ... + 20^2 = 1540`）。
#
# ### 練習題 5：使用 `for` 迴圈及 `zip()` 函數列印遊戲怪物資訊
#
# **描述**：寫一段程式碼，定義三個清單，分別儲存怪物名稱、克制怪物的武器和可以得到的分數。然後，使用 `for` 迴圈和 `zip()` 函數來顯示怪物的資訊。
#
# **要求**：
# 1. 定義三個清單：
#    - `monsters`：怪物名稱
#    - `weapons`：克制怪物的武器
#    - `scores`：擊敗怪物可以得到的分數
# 2. 首先，使用 `for` 迴圈遍歷這三個清單，列印每個怪物的資訊，格式為：`怪物 {怪物} 可以被 {武器} 所打敗，可以得到的分數為 {分數}`。
# 3. 接著，使用 `zip()` 函數合併這三個清單，並再次列印每個怪物的資訊。
#
# **範例清單**：
# ```python
# monsters = ["Spider", "Zombie", "Creeper"]
# weapons = ["Sword", "Bow", "TNT"]
# scores = [100, 50, 150]
# ```
